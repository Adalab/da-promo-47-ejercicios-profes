# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer


# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df = pd.read_json("./files/spaceX_Lunch.json")
df.head()
# Out:
#                                             fairings  \
# 0  {'reused': False, 'recovery_attempt': False, '...
# 1  {'reused': False, 'recovery_attempt': False, '...
# 2  {'reused': False, 'recovery_attempt': False, '...
# 3  {'reused': False, 'recovery_attempt': False, '...
# 4  {'reused': False, 'recovery_attempt': False, '...
#
#                                                links  \
# 0  {'patch': {'small': 'https://images2.imgbox.co...
# 1  {'patch': {'small': 'https://images2.imgbox.co...
# 2  {'patch': {'small': 'https://images2.imgbox.co...
# 3  {'patch': {'small': 'https://images2.imgbox.co...
# 4  {'patch': {'small': 'https://images2.imgbox.co...
#
#        static_fire_date_utc  static_fire_date_unix    net  window  \
# 0  2006-03-17T00:00:00.000Z           1.142554e+09  False     0.0
# 1                      None                    NaN  False     0.0
# 2                      None                    NaN  False     0.0
# 3  2008-09-20T00:00:00.000Z           1.221869e+09  False     0.0
# 4                      None                    NaN  False     0.0
#
#                      rocket  success  \
# 0  5e9d0d95eda69955f709d1eb      0.0
# 1  5e9d0d95eda69955f709d1eb      0.0
# 2  5e9d0d95eda69955f709d1eb      0.0
# 3  5e9d0d95eda69955f709d1eb      1.0
# 4  5e9d0d95eda69955f709d1eb      1.0
#
#                                             failures  \
# 0  [{'time': 33, 'altitude': None, 'reason': 'mer...
# 1  [{'time': 301, 'altitude': 289, 'reason': 'har...
# 2  [{'time': 140, 'altitude': 35, 'reason': 'resi...
# 3                                                 []
# 4                                                 []
#
#                                              details crew ships capsules  \
# 0   Engine failure at 33 seconds and loss of vehicle   []    []       []
# 1  Successful first stage burn and transition to ...   []    []       []
# 2  Residual stage 1 thrust led to collision betwe...   []    []       []
# 3  Ratsat was carried to orbit on the first succe...   []    []       []
# 4                                               None   []    []       []
#
#                                             payloads  \
# 0                         [5eb0e4b5b6c3bb0006eeb1e1]
# 1                         [5eb0e4b6b6c3bb0006eeb1e2]
# 2  [5eb0e4b6b6c3bb0006eeb1e3, 5eb0e4b6b6c3bb0006e...
# 3                         [5eb0e4b7b6c3bb0006eeb1e5]
# 4                         [5eb0e4b7b6c3bb0006eeb1e6]
#
#                   launchpad  flight_number         name  \
# 0  5e9e4502f5090995de566f86              1    FalconSat
# 1  5e9e4502f5090995de566f86              2      DemoSat
# 2  5e9e4502f5090995de566f86              3  Trailblazer
# 3  5e9e4502f5090995de566f86              4       RatSat
# 4  5e9e4502f5090995de566f86              5     RazakSat
#
#                    date_utc   date_unix                 date_local  \
# 0  2006-03-24T22:30:00.000Z  1143239400  2006-03-25T10:30:00+12:00
# 1  2007-03-21T01:10:00.000Z  1174439400  2007-03-21T13:10:00+12:00
# 2  2008-08-03T03:34:00.000Z  1217734440  2008-08-03T15:34:00+12:00
# 3  2008-09-28T23:15:00.000Z  1222643700  2008-09-28T11:15:00+12:00
# 4  2009-07-13T03:35:00.000Z  1247456100  2009-07-13T15:35:00+12:00
#
#   date_precision  upcoming                                              cores  \
# 0           hour     False  [{'core': '5e9e289df35918033d3b2623', 'flight'...
# 1           hour     False  [{'core': '5e9e289ef35918416a3b2624', 'flight'...
# 2           hour     False  [{'core': '5e9e289ef3591814873b2625', 'flight'...
# 3           hour     False  [{'core': '5e9e289ef3591855dc3b2626', 'flight'...
# 4           hour     False  [{'core': '5e9e289ef359184f103b2627', 'flight'...
#
#    auto_update    tbd launch_library_id                        id
# 0         True  False              None  5eb87cd9ffd86e000604b32a
# 1         True  False              None  5eb87cdaffd86e000604b32b
# 2         True  False              None  5eb87cdbffd86e000604b32c
# 3         True  False              None  5eb87cdbffd86e000604b32d
# 4         True  False              None  5eb87cdcffd86e000604b32e

# %% [markdown]
# # Exploración del DataFrame

# %%
# ¿Cuántas filas y columnas hay?
df.shape
# Out:
# (205, 27)

# %%
# ¿Cuáles son los nombres de las columnas?
df.columns
# Out:
# Index(['fairings', 'links', 'static_fire_date_utc', 'static_fire_date_unix',
#        'net', 'window', 'rocket', 'success', 'failures', 'details', 'crew',
#        'ships', 'capsules', 'payloads', 'launchpad', 'flight_number', 'name',
#        'date_utc', 'date_unix', 'date_local', 'date_precision', 'upcoming',
#        'cores', 'auto_update', 'tbd', 'launch_library_id', 'id'],
#       dtype='object')

# %%
# información general del conjunto de dato
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   fairings               169 non-null    object
#  1   links                  205 non-null    object
#  2   static_fire_date_utc   121 non-null    object
#  3   static_fire_date_unix  121 non-null    float64
#  4   net                    205 non-null    bool
#  5   window                 117 non-null    float64
#  6   rocket                 205 non-null    object
#  7   success                186 non-null    float64
#  8   failures               205 non-null    object
#  9   details                134 non-null    object
#  10  crew                   205 non-null    object
#  11  ships                  205 non-null    object
#  12  capsules               205 non-null    object
#  13  payloads               205 non-null    object
#  14  launchpad              205 non-null    object
#  15  flight_number          205 non-null    int64
#  16  name                   205 non-null    object
#  17  date_utc               205 non-null    object
#  18  date_unix              205 non-null    int64
#  19  date_local             205 non-null    object
#  20  date_precision         205 non-null    object
#  21  upcoming               205 non-null    bool
#  22  cores                  205 non-null    object
#  23  auto_update            205 non-null    bool
#  24  tbd                    205 non-null    bool
#  25  launch_library_id      72 non-null     object
#  26  id                     205 non-null    object
# dtypes: bool(4), float64(3), int64(2), object(18)
# memory usage: 37.8+ KB

# %%
# principales estadisticos de todas las columnas
display(df.describe().T)
print(".............")
display(df.describe(include = "O").T)
# Out:
#                        count          mean           std           min  \
# static_fire_date_unix  121.0  1.520206e+09  9.080036e+07  1.142554e+09
# window                 117.0  2.568974e+03  4.389948e+03  0.000000e+00
# success                186.0  9.731183e-01  1.621743e-01  0.000000e+00
# flight_number          205.0  1.028146e+02  5.902911e+01  1.000000e+00
# date_unix              205.0  1.566077e+09  1.037329e+08  1.143239e+09
#
#                                 25%           50%           75%           max
# static_fire_date_unix  1.475417e+09  1.529789e+09  1.589368e+09  1.650464e+09
# window                 0.000000e+00  0.000000e+00  5.280000e+03  1.830000e+04
# success                1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# flight_number          5.200000e+01  1.030000e+02  1.540000e+02  2.030000e+02
# date_unix              1.513992e+09  1.601984e+09  1.647660e+09  1.670198e+09
# .............
#                      count unique  \
# fairings               169     38
# links                  205    191
# static_fire_date_utc   121    121
# rocket                 205      3
# failures               205      6
# details                134    133
# crew                   205      9
# ships                  205     90
# capsules               205     22
# payloads               205    192
# launchpad              205      4
# name                   205    205
# date_utc               205    199
# date_local             205    200
# date_precision         205      3
# cores                  205    191
# launch_library_id       72     72
# id                     205    205
#
#                                                                     top freq
# fairings              {'reused': None, 'recovery_attempt': None, 're...   61
# links                 {'patch': {'small': None, 'large': None}, 'red...   15
# static_fire_date_utc                           2006-03-17T00:00:00.000Z    1
# rocket                                         5e9d0d95eda69973a809d1ec  195
# failures                                                             []  200
# details               This mission launches the eighteenth batch of ...    2
# crew                                                                 []  197
# ships                                                                []   85
# capsules                                                             []  170
# payloads                                                             []   12
# launchpad                                      5e9e4501f509094ba4566f84  112
# name                                                          FalconSat    1
# date_utc                                       2022-12-01T00:00:00.000Z    5
# date_local                                    2022-11-30T19:00:00-05:00    4
# date_precision                                                     hour  192
# cores                 [{'core': None, 'flight': None, 'gridfins': Tr...   10
# launch_library_id                  f31702e8-6353-4c9a-932c-5bd104717500    1
# id                                             5eb87cd9ffd86e000604b32a    1

# %%
# seleccionamos variables categoricas para ver sus valores unicos:
df_cat = df.select_dtypes(include = "O")
df_cat.head()

for col in df_cat.columns:
    print("Los valores unicos para la columna: ", col.upper())
    display(df[col].value_counts().reset_index().head())
# Out:
# Los valores unicos para la columna:  FAIRINGS
#                                                index  fairings
# 0  {'reused': None, 'recovery_attempt': None, 're...        61
# 1  {'reused': False, 'recovery_attempt': False, '...        49
# 2  {'reused': False, 'recovery_attempt': True, 'r...         9
# 3  {'reused': None, 'recovery_attempt': True, 're...         3
# 4  {'reused': False, 'recovery_attempt': True, 'r...         3
# Los valores unicos para la columna:  LINKS
#                                                index  links
# 0  {'patch': {'small': None, 'large': None}, 'red...     15
# 1  {'patch': {'small': 'https://images2.imgbox.co...      1
# 2  {'patch': {'small': 'https://images2.imgbox.co...      1
# 3  {'patch': {'small': 'https://images2.imgbox.co...      1
# 4  {'patch': {'small': 'https://images2.imgbox.co...      1
# Los valores unicos para la columna:  STATIC_FIRE_DATE_UTC
#                       index  static_fire_date_utc
# 0  2006-03-17T00:00:00.000Z                     1
# 1  2018-07-18T21:00:00.000Z                     1
# 2  2020-04-17T11:48:00.000Z                     1
# 3  2020-03-13T18:37:00.000Z                     1
# 4  2020-03-01T10:20:00.000Z                     1
# Los valores unicos para la columna:  ROCKET
#                       index  rocket
# 0  5e9d0d95eda69973a809d1ec     195
# 1  5e9d0d95eda69955f709d1eb       5
# 2  5e9d0d95eda69974db09d1ed       5
# Los valores unicos para la columna:  FAILURES
#                                                index  failures
# 0                                                 []       200
# 1  [{'time': 33, 'altitude': None, 'reason': 'mer...         1
# 2  [{'time': 301, 'altitude': 289, 'reason': 'har...         1
# 3  [{'time': 140, 'altitude': 35, 'reason': 'resi...         1
# 4  [{'time': 139, 'altitude': 40, 'reason': 'heli...         1
# Los valores unicos para la columna:  DETAILS
#                                                index  details
# 0  This mission launches the eighteenth batch of ...        2
# 1   Engine failure at 33 seconds and loss of vehicle        1
# 2  The sixth Starlink launch overall and the fift...        1
# 3  This mission will launch the fourteenth batch ...        1
# 4  This mission will launch the thirteenth batch ...        1
# Los valores unicos para la columna:  CREW
#                                                index  crew
# 0                                                 []   197
# 1  [{'crew': '5ebf1a6e23a9a60006e03a7a', 'role': ...     1
# 2  [{'crew': '5f7f1543bf32c864a529b23e', 'role': ...     1
# 3  [{'crew': '5fe3ba5fb3467846b3242188', 'role': ...     1
# 4  [{'crew': '607a3a5f5a906a44023e0870', 'role': ...     1
# Los valores unicos para la columna:  SHIPS
#                                                index  ships
# 0                                                 []     85
# 1  [5ea6ed2e080df4000697c906, 5ea6ed2f080df400069...      6
# 2                         [5ea6ed30080df4000697c912]      6
# 3                         [5ea6ed2d080df4000697c902]      4
# 4                         [5ea6ed30080df4000697c913]      4
# Los valores unicos para la columna:  CAPSULES
#                         index  capsules
# 0                          []       170
# 1  [5e9e2c5df359188aba3b2676]         3
# 2  [5e9e2c5bf3591880643b2669]         3
# 3  [5e9e2c5cf359188bfb3b266b]         3
# 4  [5e9e2c5cf359185d753b266f]         3
# Los valores unicos para la columna:  PAYLOADS
#                         index  payloads
# 0                          []        12
# 1  [6175aaacefa4314085aa9c56]         2
# 2  [6243b788af52800c6e91926b]         2
# 3  [608ac397eb3e50044e3630e7]         1
# 4  [5fe3b3adb3467846b3242173]         1
# Los valores unicos para la columna:  LAUNCHPAD
#                       index  launchpad
# 0  5e9e4501f509094ba4566f84        112
# 1  5e9e4502f509094188566f88         58
# 2  5e9e4502f509092b78566f87         30
# 3  5e9e4502f5090995de566f86          5
# Los valores unicos para la columna:  NAME
#                  index  name
# 0            FalconSat     1
# 1           Türksat 5B     1
# 2        Transporter-2     1
# 3               CRS-23     1
# 4  Starlink 2-1 (v1.5)     1
# Los valores unicos para la columna:  DATE_UTC
#                       index  date_utc
# 0  2022-12-01T00:00:00.000Z         5
# 1  2022-11-01T00:00:00.000Z         3
# 2  2021-11-24T06:20:00.000Z         1
# 3  2021-05-26T18:59:00.000Z         1
# 4  2021-06-03T17:29:00.000Z         1
# Los valores unicos para la columna:  DATE_LOCAL
#                        index  date_local
# 0  2022-11-30T19:00:00-05:00           4
# 1  2022-10-31T20:00:00-04:00           3
# 2  2006-03-25T10:30:00+12:00           1
# 3  2021-11-23T22:20:00-08:00           1
# 4  2021-05-26T14:59:00-04:00           1
# Los valores unicos para la columna:  DATE_PRECISION
#    index  date_precision
# 0   hour             192
# 1  month               8
# 2    day               5
# Los valores unicos para la columna:  CORES
#                                                index  cores
# 0  [{'core': None, 'flight': None, 'gridfins': Tr...     10
# 1  [{'core': None, 'flight': None, 'gridfins': No...      6
# 2  [{'core': '5e9e289df35918033d3b2623', 'flight'...      1
# 3  [{'core': '5f57c5440622a633027900a0', 'flight'...      1
# 4  [{'core': '5e9e28a7f3591817f23b2663', 'flight'...      1
# Los valores unicos para la columna:  LAUNCH_LIBRARY_ID
#                                   index  launch_library_id
# 0  f31702e8-6353-4c9a-932c-5bd104717500                  1
# 1  985f1cc1-82c1-4a89-b2cc-e9dc91829a0e                  1
# 2  33223258-614c-449c-8af7-a9f75cc036b2                  1
# 3  4ca945f6-981f-4ee9-8a79-f1204b785f8c                  1
# 4  179789f0-9380-4182-8ea2-676504c2f890                  1
# Los valores unicos para la columna:  ID
#                       index  id
# 0  5eb87cd9ffd86e000604b32a   1
# 1  5fe3afc1b3467846b3242164   1
# 2  600f9b6d8f798e2a4d5f979f   1
# 3  5fe3b11eb3467846b324216c   1
# 4  60e3bf0d73359e1e20335c37   1

# %%
# ¿Hay valores duplicados? no se puede hacer porque tenemos columnas que son de tipo lista y pandas no permite contar duplicados si tenemos este tipo de dato
df.duplicated().sum()

# %%
# ¿Alguna solución?
# CONTAR LOS DUPLICADOS USANDO EL SUBSET, podemos usar el id del lanzamiento que es único y verificar sino esta duplicado
df.duplicated(subset = "id").sum()
# Out:
# 0

# %%
# vamos a ver que columnas tienen valores nulos
df.isnull().sum()[df.isnull().sum() > 0] / df.shape[0]
# Out:
# fairings                 0.175610
# static_fire_date_utc     0.409756
# static_fire_date_unix    0.409756
# window                   0.429268
# success                  0.092683
# details                  0.346341
# launch_library_id        0.648780
# dtype: float64

# %% [markdown]
# # Limpieza del DataFrame

# %%
# tenemos dos columnas que nos dan la misma info, 'static_fire_date_utc' y ' static_fire_date_unix'
# eliminamos la columna de unix que es menos ituitiva
df.drop("static_fire_date_unix", axis = 1, inplace = True)
df.head(1)
# Out:
#                                             fairings  \
# 0  {'reused': False, 'recovery_attempt': False, '...
#
#                                                links  \
# 0  {'patch': {'small': 'https://images2.imgbox.co...
#
#        static_fire_date_utc    net  window                    rocket  success  \
# 0  2006-03-17T00:00:00.000Z  False     0.0  5e9d0d95eda69955f709d1eb      0.0
#
#                                             failures  \
# 0  [{'time': 33, 'altitude': None, 'reason': 'mer...
#
#                                             details crew ships capsules  \
# 0  Engine failure at 33 seconds and loss of vehicle   []    []       []
#
#                      payloads                 launchpad  flight_number  \
# 0  [5eb0e4b5b6c3bb0006eeb1e1]  5e9e4502f5090995de566f86              1
#
#         name                  date_utc   date_unix                 date_local  \
# 0  FalconSat  2006-03-24T22:30:00.000Z  1143239400  2006-03-25T10:30:00+12:00
#
#   date_precision  upcoming                                              cores  \
# 0           hour     False  [{'core': '5e9e289df35918033d3b2623', 'flight'...
#
#    auto_update    tbd launch_library_id                        id
# 0         True  False              None  5eb87cd9ffd86e000604b32a

# %%
# la columna 'flight_number' es el número único de lanzamiento, pero si exploramos los duplicados en esa columna vemos que tenemos 4 duplicados, 
# por lo no tiene mucho sentido que sea único, por lo la eliminaremos
df["flight_number"].duplicated().sum()
# Out:
# 4

# %%
df.drop("flight_number", axis = 1, inplace = True)
# chequeamos si se ha eliminado la columna correctamente
df.head(1)
# Out:
#                                             fairings  \
# 0  {'reused': False, 'recovery_attempt': False, '...
#
#                                                links  \
# 0  {'patch': {'small': 'https://images2.imgbox.co...
#
#        static_fire_date_utc    net  window                    rocket  success  \
# 0  2006-03-17T00:00:00.000Z  False     0.0  5e9d0d95eda69955f709d1eb      0.0
#
#                                             failures  \
# 0  [{'time': 33, 'altitude': None, 'reason': 'mer...
#
#                                             details crew ships capsules  \
# 0  Engine failure at 33 seconds and loss of vehicle   []    []       []
#
#                      payloads                 launchpad       name  \
# 0  [5eb0e4b5b6c3bb0006eeb1e1]  5e9e4502f5090995de566f86  FalconSat
#
#                    date_utc   date_unix                 date_local  \
# 0  2006-03-24T22:30:00.000Z  1143239400  2006-03-25T10:30:00+12:00
#
#   date_precision  upcoming                                              cores  \
# 0           hour     False  [{'core': '5e9e289df35918033d3b2623', 'flight'...
#
#    auto_update    tbd launch_library_id                        id
# 0         True  False              None  5eb87cd9ffd86e000604b32a

# %%
# la columna 'success' esta con 0 y 1, lo cual es poco intuitivo. Vamos a sustituir los valores por "fracaso" y "exito"
mapa = {0: "Fracaso", 1: "Exito"}

# sobreescribimos el cambio en la columna original
df["success"] = df["success"].map(mapa)

# evaluamos que el cambio se realizó con exito
df["success"].unique()
# Out:
# array(['Fracaso', 'Exito', nan], dtype=object)

# %%
# tenemos la columna de 'window' que esta en segundos, vamos a convertirla a minutos. 
df["window_min"] = df["window"].apply(lambda x: x / 60)
df.head(1)
# Out:
#                                             fairings  \
# 0  {'reused': False, 'recovery_attempt': False, '...
#
#                                                links  \
# 0  {'patch': {'small': 'https://images2.imgbox.co...
#
#        static_fire_date_utc    net  window                    rocket  success  \
# 0  2006-03-17T00:00:00.000Z  False     0.0  5e9d0d95eda69955f709d1eb  Fracaso
#
#                                             failures  \
# 0  [{'time': 33, 'altitude': None, 'reason': 'mer...
#
#                                             details crew ships capsules  \
# 0  Engine failure at 33 seconds and loss of vehicle   []    []       []
#
#                      payloads                 launchpad       name  \
# 0  [5eb0e4b5b6c3bb0006eeb1e1]  5e9e4502f5090995de566f86  FalconSat
#
#                    date_utc   date_unix                 date_local  \
# 0  2006-03-24T22:30:00.000Z  1143239400  2006-03-25T10:30:00+12:00
#
#   date_precision  upcoming                                              cores  \
# 0           hour     False  [{'core': '5e9e289df35918033d3b2623', 'flight'...
#
#    auto_update    tbd launch_library_id                        id  window_min
# 0         True  False              None  5eb87cd9ffd86e000604b32a         0.0

# %%
df["fairings"][0]
# Out:
# {'reused': False, 'recovery_attempt': False, 'recovered': False, 'ships': []}

# %%
# descomprimimos la columna de "fairings"
df[["reused", "recovery_attempt", "recovered"]] = df["fairings"].apply(pd.Series).iloc[:, :3] #"selecciona todas las filas (:) y solo las primeras tres columnas (:3)
df.head(1)
# Out:
#                                             fairings  \
# 0  {'reused': False, 'recovery_attempt': False, '...
#
#                                                links  \
# 0  {'patch': {'small': 'https://images2.imgbox.co...
#
#        static_fire_date_utc    net  window                    rocket  success  \
# 0  2006-03-17T00:00:00.000Z  False     0.0  5e9d0d95eda69955f709d1eb  Fracaso
#
#                                             failures  \
# 0  [{'time': 33, 'altitude': None, 'reason': 'mer...
#
#                                             details crew ships capsules  \
# 0  Engine failure at 33 seconds and loss of vehicle   []    []       []
#
#                      payloads                 launchpad       name  \
# 0  [5eb0e4b5b6c3bb0006eeb1e1]  5e9e4502f5090995de566f86  FalconSat
#
#                    date_utc   date_unix                 date_local  \
# 0  2006-03-24T22:30:00.000Z  1143239400  2006-03-25T10:30:00+12:00
#
#   date_precision  upcoming                                              cores  \
# 0           hour     False  [{'core': '5e9e289df35918033d3b2623', 'flight'...
#
#    auto_update    tbd launch_library_id                        id  window_min  \
# 0         True  False              None  5eb87cd9ffd86e000604b32a         0.0
#
#   reused recovery_attempt recovered
# 0  False            False     False

# %%
# hacemos lo mismo con la columna links
df[["webcast", "article"]] = df["links"].apply(pd.Series)[["webcast", "article"]]
df.head(1)
# Out:
#                                             fairings  \
# 0  {'reused': False, 'recovery_attempt': False, '...
#
#                                                links  \
# 0  {'patch': {'small': 'https://images2.imgbox.co...
#
#        static_fire_date_utc    net  window                    rocket  success  \
# 0  2006-03-17T00:00:00.000Z  False     0.0  5e9d0d95eda69955f709d1eb  Fracaso
#
#                                             failures  \
# 0  [{'time': 33, 'altitude': None, 'reason': 'mer...
#
#                                             details crew ships capsules  \
# 0  Engine failure at 33 seconds and loss of vehicle   []    []       []
#
#                      payloads                 launchpad       name  \
# 0  [5eb0e4b5b6c3bb0006eeb1e1]  5e9e4502f5090995de566f86  FalconSat
#
#                    date_utc   date_unix                 date_local  \
# 0  2006-03-24T22:30:00.000Z  1143239400  2006-03-25T10:30:00+12:00
#
#   date_precision  upcoming                                              cores  \
# 0           hour     False  [{'core': '5e9e289df35918033d3b2623', 'flight'...
#
#    auto_update    tbd launch_library_id                        id  window_min  \
# 0         True  False              None  5eb87cd9ffd86e000604b32a         0.0
#
#   reused recovery_attempt recovered  \
# 0  False            False     False
#
#                                        webcast  \
# 0  https://www.youtube.com/watch?v=0a_00nJ_Y88
#
#                                              article
# 0  https://www.space.com/2196-spacex-inaugural-fa...

# %%
df[["time", "altitude", "reason"]] =  df["failures"].apply(pd.Series)[0].apply(pd.Series).iloc[:, :3]
df.head(1)
# Out:
#                                             fairings  \
# 0  {'reused': False, 'recovery_attempt': False, '...
#
#                                                links  \
# 0  {'patch': {'small': 'https://images2.imgbox.co...
#
#        static_fire_date_utc    net  window                    rocket  success  \
# 0  2006-03-17T00:00:00.000Z  False     0.0  5e9d0d95eda69955f709d1eb  Fracaso
#
#                                             failures  \
# 0  [{'time': 33, 'altitude': None, 'reason': 'mer...
#
#                                             details crew ships capsules  \
# 0  Engine failure at 33 seconds and loss of vehicle   []    []       []
#
#                      payloads                 launchpad       name  \
# 0  [5eb0e4b5b6c3bb0006eeb1e1]  5e9e4502f5090995de566f86  FalconSat
#
#                    date_utc   date_unix                 date_local  \
# 0  2006-03-24T22:30:00.000Z  1143239400  2006-03-25T10:30:00+12:00
#
#   date_precision  upcoming                                              cores  \
# 0           hour     False  [{'core': '5e9e289df35918033d3b2623', 'flight'...
#
#    auto_update    tbd launch_library_id                        id  window_min  \
# 0         True  False              None  5eb87cd9ffd86e000604b32a         0.0
#
#   reused recovery_attempt recovered  \
# 0  False            False     False
#
#                                        webcast  \
# 0  https://www.youtube.com/watch?v=0a_00nJ_Y88
#
#                                              article  time  altitude  \
# 0  https://www.space.com/2196-spacex-inaugural-fa...   NaN       NaN
#
#                   reason
# 0  merlin engine failure

# %%
# eliminamos las columnas que hemos descomprimido
df.drop(["fairings", "links", "failures"], axis = 1, inplace = True)
df.sample(2)
# Out:
#          static_fire_date_utc    net  window                    rocket  \
# 40   2017-05-28T16:00:00.000Z  False     0.0  5e9d0d95eda69973a809d1ec
# 154                      None  False     NaN  5e9d0d95eda69973a809d1ec
#
#     success                                            details crew  \
# 40    Exito  This mission delivered the Neutron Star Interi...   []
# 154   Exito                                               None   []
#
#                           ships                    capsules  \
# 40   [5ea6ed30080df4000697c912]  [5e9e2c5bf3591880643b2669]
# 154                          []                          []
#
#                        payloads                 launchpad           name  \
# 40   [5eb0e4c4b6c3bb0006eeb20e]  5e9e4502f509094188566f88         CRS-11
# 154  [6243af62af52800c6e919260]  5e9e4501f509094ba4566f84  Transporter-4
#
#                      date_utc   date_unix                 date_local  \
# 40   2017-06-03T21:07:00.000Z  1496524020  2017-06-03T17:07:00-04:00
# 154  2022-04-01T16:24:00.000Z  1648830240  2022-04-01T12:24:00-04:00
#
#     date_precision  upcoming  \
# 40            hour     False
# 154           hour     False
#
#                                                  cores  auto_update    tbd  \
# 40   [{'core': '5e9e28a3f3591856803b264a', 'flight'...         True  False
# 154  [{'core': '5f57c53d0622a6330279009f', 'flight'...         True  False
#
#                         launch_library_id                        id  \
# 40                                   None  5eb87d03ffd86e000604b352
# 154  335acce9-a35c-436c-9a22-a2505f20957f  6243ad8baf52800c6e919252
#
#      window_min reused recovery_attempt recovered  \
# 40          0.0    NaN              NaN       NaN
# 154         NaN   None             None      None
#
#                                          webcast  \
# 40   https://www.youtube.com/watch?v=JuZBOUMsYws
# 154                 https://youtu.be/4NqSoHnkKEM
#
#                                                article  time  altitude reason
# 40   https://spaceflightnow.com/2017/06/03/reused-d...   NaN       NaN    NaN
# 154  https://spaceflightnow.com/2022/04/01/forty-pa...   NaN       NaN    NaN

# %%
df['static_fire_date_utc'].isnull().sum()
df['static_fire_date_utc'].fillna("1677-09-21 00:12:43.145224193")
# Out:
# 0      1677-09-21 00:12:43.145224193
# 1      1677-09-21 00:12:43.145224193
# 2      1677-09-21 00:12:43.145224193
# 3      1677-09-21 00:12:43.145224193
# 4      1677-09-21 00:12:43.145224193
#                    ...
# 200    1677-09-21 00:12:43.145224193
# 201    1677-09-21 00:12:43.145224193
# 202    1677-09-21 00:12:43.145224193
# 203    1677-09-21 00:12:43.145224193
# 204    1677-09-21 00:12:43.145224193
# Name: static_fire_date_utc, Length: 205, dtype: object

# %%
# convertimos la columna de fecha a formato datetime
df["static_fire_date_utc"] = pd.to_datetime(df["static_fire_date_utc"])

# %%
# creamos la columna de año y mes
df[['year', 'month']] = df['static_fire_date_utc'].apply(lambda x: pd.Series([x.year, x.month]))
df.head()
# Out:
#   static_fire_date_utc    net  window                    rocket  success  \
# 0                  NaT  False     0.0  5e9d0d95eda69955f709d1eb  Fracaso
# 1                  NaT  False     0.0  5e9d0d95eda69955f709d1eb  Fracaso
# 2                  NaT  False     0.0  5e9d0d95eda69955f709d1eb  Fracaso
# 3                  NaT  False     0.0  5e9d0d95eda69955f709d1eb    Exito
# 4                  NaT  False     0.0  5e9d0d95eda69955f709d1eb    Exito
#
#                                              details crew ships capsules  \
# 0   Engine failure at 33 seconds and loss of vehicle   []    []       []
# 1  Successful first stage burn and transition to ...   []    []       []
# 2  Residual stage 1 thrust led to collision betwe...   []    []       []
# 3  Ratsat was carried to orbit on the first succe...   []    []       []
# 4                                            Unknown   []    []       []
#
#                                             payloads  \
# 0                         [5eb0e4b5b6c3bb0006eeb1e1]
# 1                         [5eb0e4b6b6c3bb0006eeb1e2]
# 2  [5eb0e4b6b6c3bb0006eeb1e3, 5eb0e4b6b6c3bb0006e...
# 3                         [5eb0e4b7b6c3bb0006eeb1e5]
# 4                         [5eb0e4b7b6c3bb0006eeb1e6]
#
#                   launchpad         name                  date_utc  \
# 0  5e9e4502f5090995de566f86    FalconSat  2006-03-24T22:30:00.000Z
# 1  5e9e4502f5090995de566f86      DemoSat  2007-03-21T01:10:00.000Z
# 2  5e9e4502f5090995de566f86  Trailblazer  2008-08-03T03:34:00.000Z
# 3  5e9e4502f5090995de566f86       RatSat  2008-09-28T23:15:00.000Z
# 4  5e9e4502f5090995de566f86     RazakSat  2009-07-13T03:35:00.000Z
#
#     date_unix                 date_local date_precision  upcoming  \
# 0  1143239400  2006-03-25T10:30:00+12:00           hour     False
# 1  1174439400  2007-03-21T13:10:00+12:00           hour     False
# 2  1217734440  2008-08-03T15:34:00+12:00           hour     False
# 3  1222643700  2008-09-28T11:15:00+12:00           hour     False
# 4  1247456100  2009-07-13T15:35:00+12:00           hour     False
#
#                                                cores  auto_update    tbd  \
# 0  [{'core': '5e9e289df35918033d3b2623', 'flight'...         True  False
# 1  [{'core': '5e9e289ef35918416a3b2624', 'flight'...         True  False
# 2  [{'core': '5e9e289ef3591814873b2625', 'flight'...         True  False
# 3  [{'core': '5e9e289ef3591855dc3b2626', 'flight'...         True  False
# 4  [{'core': '5e9e289ef359184f103b2627', 'flight'...         True  False
#
#   launch_library_id                        id  window_min reused  \
# 0           Unknown  5eb87cd9ffd86e000604b32a         0.0  False
# 1           Unknown  5eb87cdaffd86e000604b32b         0.0  False
# 2           Unknown  5eb87cdbffd86e000604b32c         0.0  False
# 3           Unknown  5eb87cdbffd86e000604b32d         0.0  False
# 4           Unknown  5eb87cdcffd86e000604b32e         0.0  False
#
#   recovery_attempt recovered                                      webcast  \
# 0            False     False  https://www.youtube.com/watch?v=0a_00nJ_Y88
# 1            False     False  https://www.youtube.com/watch?v=Lk4zQ2wP-Nc
# 2            False     False  https://www.youtube.com/watch?v=v0w9p3U8860
# 3            False     False  https://www.youtube.com/watch?v=dLQ2tZEH6G0
# 4            False     False  https://www.youtube.com/watch?v=yTaIDooc8Og
#
#                                              article  time  altitude  \
# 0  https://www.space.com/2196-spacex-inaugural-fa...   NaN       NaN
# 1  https://www.space.com/3590-spacex-falcon-1-roc...   NaN     289.0
# 2  http://www.spacex.com/news/2013/02/11/falcon-1...   NaN      35.0
# 3               https://en.wikipedia.org/wiki/Ratsat   NaN       NaN
# 4  http://www.spacex.com/news/2013/02/12/falcon-1...   NaN       NaN
#
#                                               reason  year  month
# 0                              merlin engine failure   NaN    NaN
# 1  harmonic oscillation leading to premature engi...   NaN    NaN
# 2  residual stage-1 thrust led to collision betwe...   NaN    NaN
# 3                                            Unknown   NaN    NaN
# 4                                            Unknown   NaN    NaN

# %% [markdown]
# # Gestión de nulos

# %%
nulos_esta_cat = df[df.columns[df.isnull().any()]].select_dtypes(include = "O").columns
print("Las columnas categóricas que tienen nulos son : \n ")
print(nulos_esta_cat)
# Out:
# Las columnas categóricas que tienen nulos son :
#
# Index(['success', 'details', 'launch_library_id', 'reused', 'recovery_attempt',
#        'recovered', 'webcast', 'article', 'reason'],
#       dtype='object')

# %%
# para todas las columnas tiene mas sentido reemplazar por desconocido
# iteramos por la lista de columnas a las que le vamos a cambiar los nulos por "Uknown"
for columna in nulos_esta_cat:
    
    # reemplazamos los nulos por el valor Unknown para cada una de las columnas de la lista
    df[columna] = df[columna].fillna("Unknown")
    
# comprobamos si quedan nulos en las columnas categóricas. 
print("Después del reemplazo usando 'fillna' quedan los siguientes nulos")
df[nulos_esta_cat].isnull().sum()
# Out:
# Después del reemplazo usando 'fillna' quedan los siguientes nulos
# success              0
# details              0
# launch_library_id    0
# reused               0
# recovery_attempt     0
# recovered            0
# webcast              0
# article              0
# reason               0
# dtype: int64

# %%
nulos_esta_num = df[df.columns[df.isnull().any()]].select_dtypes(include = np.number).columns
print("Las columnas numéricas que tienen nulos son : \n ")
print(nulos_esta_num)
# Out:
# Las columnas numéricas que tienen nulos son :
#
# Index(['window', 'window_min', 'time', 'altitude', 'year', 'month'], dtype='object')

# %%
# ¿ que hago con esas columnas con nulos?
df['year'].isnull().sum()/df.shape[0]
# Out:
# 0.4097560975609756

# %% [markdown]
# # Filtrado de Datos

# %%
# ¿Qué cohetes se han lanzado entre el 2000 y el 2010? 
df[df["year"].between(2000, 2010)]
# Out:
#        static_fire_date_utc    net  window                    rocket  success  \
# 0 2006-03-17 00:00:00+00:00  False     0.0  5e9d0d95eda69955f709d1eb  Fracaso
# 3 2008-09-20 00:00:00+00:00  False     0.0  5e9d0d95eda69955f709d1eb    Exito
# 5 2010-03-13 00:00:00+00:00  False     0.0  5e9d0d95eda69973a809d1ec    Exito
# 6 2010-12-04 00:00:00+00:00  False     0.0  5e9d0d95eda69973a809d1ec    Exito
#
#                                              details crew  \
# 0   Engine failure at 33 seconds and loss of vehicle   []
# 3  Ratsat was carried to orbit on the first succe...   []
# 5                                            Unknown   []
# 6                                            Unknown   []
#
#                         ships                    capsules  \
# 0                          []                          []
# 3                          []                          []
# 5                          []                          []
# 6  [5ea6ed2d080df4000697c901]  [5e9e2c5bf35918ed873b2664]
#
#                                             payloads  \
# 0                         [5eb0e4b5b6c3bb0006eeb1e1]
# 3                         [5eb0e4b7b6c3bb0006eeb1e5]
# 5                         [5eb0e4b7b6c3bb0006eeb1e7]
# 6  [5eb0e4b9b6c3bb0006eeb1e8, 5eb0e4b9b6c3bb0006e...
#
#                   launchpad                  name                  date_utc  \
# 0  5e9e4502f5090995de566f86             FalconSat  2006-03-24T22:30:00.000Z
# 3  5e9e4502f5090995de566f86                RatSat  2008-09-28T23:15:00.000Z
# 5  5e9e4501f509094ba4566f84  Falcon 9 Test Flight  2010-06-04T18:45:00.000Z
# 6  5e9e4501f509094ba4566f84                COTS 1  2010-12-08T15:43:00.000Z
#
#     date_unix                 date_local date_precision  upcoming  \
# 0  1143239400  2006-03-25T10:30:00+12:00           hour     False
# 3  1222643700  2008-09-28T11:15:00+12:00           hour     False
# 5  1275677100  2010-06-04T14:45:00-04:00           hour     False
# 6  1291822980  2010-12-08T11:43:00-04:00           hour     False
#
#                                                cores  auto_update    tbd  \
# 0  [{'core': '5e9e289df35918033d3b2623', 'flight'...         True  False
# 3  [{'core': '5e9e289ef3591855dc3b2626', 'flight'...         True  False
# 5  [{'core': '5e9e289ef359185f2b3b2628', 'flight'...         True  False
# 6  [{'core': '5e9e289ef35918187c3b2629', 'flight'...         True  False
#
#   launch_library_id                        id  window_min   reused  \
# 0           Unknown  5eb87cd9ffd86e000604b32a         0.0    False
# 3           Unknown  5eb87cdbffd86e000604b32d         0.0    False
# 5           Unknown  5eb87cddffd86e000604b32f         0.0  Unknown
# 6           Unknown  5eb87cdeffd86e000604b330         0.0  Unknown
#
#   recovery_attempt recovered                                      webcast  \
# 0            False     False  https://www.youtube.com/watch?v=0a_00nJ_Y88
# 3            False     False  https://www.youtube.com/watch?v=dLQ2tZEH6G0
# 5          Unknown   Unknown  https://www.youtube.com/watch?v=nxSxgBKlYws
# 6          Unknown   Unknown  https://www.youtube.com/watch?v=cdLITgWKe_0
#
#                                              article  time  altitude  \
# 0  https://www.space.com/2196-spacex-inaugural-fa...   NaN       NaN
# 3               https://en.wikipedia.org/wiki/Ratsat   NaN       NaN
# 5  http://www.spacex.com/news/2013/02/12/falcon-9...   NaN       NaN
# 6  https://en.wikipedia.org/wiki/SpaceX_COTS_Demo...   NaN       NaN
#
#                   reason    year  month
# 0  merlin engine failure  2006.0    3.0
# 3                Unknown  2008.0    9.0
# 5                Unknown  2010.0    3.0
# 6                Unknown  2010.0   12.0

# %%
# seleccionamos aquellas filas donde 'date_precision' sea igual a day
df[df["date_precision"] == "day"]
# Out:
#     static_fire_date_utc    net  window                    rocket  success  \
# 175                  NaT  False     NaN  5e9d0d95eda69973a809d1ec    Exito
# 192                  NaT  False     NaN  5e9d0d95eda69973a809d1ec  Unknown
# 193                  NaT  False     NaN  5e9d0d95eda69973a809d1ec  Unknown
# 194                  NaT  False     NaN  5e9d0d95eda69973a809d1ec  Unknown
# 198                  NaT  False     NaN  5e9d0d95eda69973a809d1ec  Unknown
#
#      details crew ships capsules                    payloads  \
# 175  Unknown   []    []       []  [630bce79d36448026ab0163d]
# 192  Unknown   []    []       []                          []
# 193  Unknown   []    []       []                          []
# 194  Unknown   []    []       []                          []
# 198  Unknown   []    []       []                          []
#
#                     launchpad                        name  \
# 175  5e9e4501f509094ba4566f84        Starlink 4-25 (v1.5)
# 192  5e9e4501f509094ba4566f84  Galaxy 31 (23R) & 32 (17R)
# 193  5e9e4501f509094ba4566f84                Eutelsat 10B
# 194  5e9e4501f509094ba4566f84   ispace Mission 1 & Rashid
# 198  5e9e4502f509092b78566f87                        SWOT
#
#                      date_utc   date_unix                 date_local  \
# 175  2022-07-24T00:00:00.000Z  1658620800  2022-07-23T20:00:00-04:00
# 192  2022-11-08T00:00:00.000Z  1667865600  2022-11-07T19:00:00-05:00
# 193  2022-11-15T00:00:00.000Z  1668470400  2022-11-14T19:00:00-05:00
# 194  2022-11-22T00:00:00.000Z  1669075200  2022-11-21T19:00:00-05:00
# 198  2022-12-05T00:00:00.000Z  1670198400  2022-12-04T16:00:00-08:00
#
#     date_precision  upcoming  \
# 175            day     False
# 192            day      True
# 193            day      True
# 194            day      True
# 198            day      True
#
#                                                  cores  auto_update    tbd  \
# 175  [{'core': '5f57c5440622a633027900a0', 'flight'...         True  False
# 192  [{'core': None, 'flight': None, 'gridfins': Tr...         True  False
# 193  [{'core': None, 'flight': None, 'gridfins': Tr...         True  False
# 194  [{'core': None, 'flight': None, 'gridfins': Tr...         True  False
# 198  [{'core': None, 'flight': None, 'gridfins': Tr...         True  False
#
#     launch_library_id                        id  window_min   reused  \
# 175           Unknown  62a9f12820413d2695d88716         NaN  Unknown
# 192           Unknown  633f71a90531f07b4fdf59be         NaN  Unknown
# 193           Unknown  633f71b60531f07b4fdf59bf         NaN  Unknown
# 194           Unknown  633f723d0531f07b4fdf59c4         NaN  Unknown
# 198           Unknown  633f724c0531f07b4fdf59c5         NaN  Unknown
#
#     recovery_attempt recovered  webcast  article  year  month
# 175          Unknown   Unknown  Unknown  Unknown   NaN    NaN
# 192          Unknown   Unknown  Unknown  Unknown   NaN    NaN
# 193          Unknown   Unknown  Unknown  Unknown   NaN    NaN
# 194          Unknown   Unknown  Unknown  Unknown   NaN    NaN
# 198          Unknown   Unknown  Unknown  Unknown   NaN    NaN

# %%
# al resultado anterior le añadimos la condición de que sea el lanzamiento haya ocurrido con exito
df[(df["date_precision"] == "day") & (df["success"] == "Exito")]
# Out:
#     static_fire_date_utc    net  window                    rocket success  \
# 175                  NaT  False     NaN  5e9d0d95eda69973a809d1ec   Exito
#
#      details crew ships capsules                    payloads  \
# 175  Unknown   []    []       []  [630bce79d36448026ab0163d]
#
#                     launchpad                  name                  date_utc  \
# 175  5e9e4501f509094ba4566f84  Starlink 4-25 (v1.5)  2022-07-24T00:00:00.000Z
#
#       date_unix                 date_local date_precision  upcoming  \
# 175  1658620800  2022-07-23T20:00:00-04:00            day     False
#
#                                                  cores  auto_update    tbd  \
# 175  [{'core': '5f57c5440622a633027900a0', 'flight'...         True  False
#
#     launch_library_id                        id  window_min   reused  \
# 175           Unknown  62a9f12820413d2695d88716         NaN  Unknown
#
#     recovery_attempt recovered  webcast  article  time  altitude   reason  \
# 175          Unknown   Unknown  Unknown  Unknown   NaN       NaN  Unknown
#
#      year  month
# 175   NaN    NaN

# %%
# que cohetes tienen en el nombre "Falcon". 

df[df["name"].str.contains("Falcon")]
# Out:
#         static_fire_date_utc    net  window                    rocket  \
# 0  2006-03-17 00:00:00+00:00  False     0.0  5e9d0d95eda69955f709d1eb
# 5  2010-03-13 00:00:00+00:00  False     0.0  5e9d0d95eda69973a809d1ec
# 54 2018-01-24 17:30:00+00:00  False  9000.0  5e9d0d95eda69974db09d1ed
#
#     success                                            details crew  \
# 0   Fracaso   Engine failure at 33 seconds and loss of vehicle   []
# 5     Exito                                            Unknown   []
# 54    Exito  The launch was a success, and the side booster...   []
#
#                                                 ships capsules  \
# 0                                                  []       []
# 5                                                  []       []
# 54  [5ea6ed2f080df4000697c90c, 5ea6ed2f080df400069...       []
#
#                       payloads                 launchpad  \
# 0   [5eb0e4b5b6c3bb0006eeb1e1]  5e9e4502f5090995de566f86
# 5   [5eb0e4b7b6c3bb0006eeb1e7]  5e9e4501f509094ba4566f84
# 54  [5eb0e4c6b6c3bb0006eeb21c]  5e9e4502f509094188566f88
#
#                         name                  date_utc   date_unix  \
# 0                  FalconSat  2006-03-24T22:30:00.000Z  1143239400
# 5       Falcon 9 Test Flight  2010-06-04T18:45:00.000Z  1275677100
# 54  Falcon Heavy Test Flight  2018-02-06T20:45:00.000Z  1517949900
#
#                    date_local date_precision  upcoming  \
# 0   2006-03-25T10:30:00+12:00           hour     False
# 5   2010-06-04T14:45:00-04:00           hour     False
# 54  2018-02-06T15:45:00-05:00           hour     False
#
#                                                 cores  auto_update    tbd  \
# 0   [{'core': '5e9e289df35918033d3b2623', 'flight'...         True  False
# 5   [{'core': '5e9e289ef359185f2b3b2628', 'flight'...         True  False
# 54  [{'core': '5e9e28a5f359187f703b2653', 'flight'...         True  False
#
#    launch_library_id                        id  window_min   reused  \
# 0            Unknown  5eb87cd9ffd86e000604b32a         0.0    False
# 5            Unknown  5eb87cddffd86e000604b32f         0.0  Unknown
# 54           Unknown  5eb87d13ffd86e000604b360       150.0    False
#
#    recovery_attempt recovered                                      webcast  \
# 0             False     False  https://www.youtube.com/watch?v=0a_00nJ_Y88
# 5           Unknown   Unknown  https://www.youtube.com/watch?v=nxSxgBKlYws
# 54            False     False  https://www.youtube.com/watch?v=wbSwFU6tY1c
#
#                                               article  time  altitude  \
# 0   https://www.space.com/2196-spacex-inaugural-fa...   NaN       NaN
# 5   http://www.spacex.com/news/2013/02/12/falcon-9...   NaN       NaN
# 54  https://spaceflightnow.com/2018/02/07/spacex-d...   NaN       NaN
#
#                    reason    year  month
# 0   merlin engine failure  2006.0    3.0
# 5                 Unknown  2010.0    3.0
# 54                Unknown  2018.0    1.0

# %% [markdown]
# # Groupby

# %%
# ¿Qué año se lanzaron mas cohetes? 
df.groupby(['year'])["id"].count().reset_index()
# Out:
#       year  id
# 0   2006.0   1
# 1   2008.0   1
# 2   2010.0   2
# 3   2012.0   2
# 4   2013.0   4
# 5   2014.0   5
# 6   2015.0   7
# 7   2016.0   9
# 8   2017.0  19
# 9   2018.0  20
# 10  2019.0  13
# 11  2020.0  21
# 12  2021.0  14
# 13  2022.0   3

# %%
# ¿Qué  mes se lanzaron mas cohetes? 
df.groupby(['month'])["id"].count().reset_index()
# Out:
#     month  id
# 0     1.0  11
# 1     2.0   9
# 2     3.0  10
# 3     4.0  12
# 4     5.0  11
# 5     6.0  13
# 6     7.0   6
# 7     8.0   9
# 8     9.0   9
# 9    10.0   8
# 10   11.0  11
# 11   12.0  12

# %%
# ¿Cuántos lanzamientos hubo con éxito? 
df.groupby("success")["id"].count().reset_index()
# Out:
#    success   id
# 0    Exito  181
# 1  Fracaso    5
# 2  Unknown   19

# %%
# hacemos lo mismo pero calculandolo en %
df_exito = df.groupby("success")["id"].count().reset_index()
df_exito['porcentaje'] = (df_exito['id'] / df_exito['id'].sum()) * 100
df_exito
# Out:
#    success   id  porcentaje
# 0    Exito  181   88.292683
# 1  Fracaso    5    2.439024
# 2  Unknown   19    9.268293

# %%
# ¿Cuál es la ventana de duración media, mínima y máxima por año?
df.groupby("year")["window_min"].agg(["mean", "min", "max", "count"]).round(2)
# Out:
#          mean  min    max  count
# year
# 2006.0   0.00  0.0    0.0      1
# 2008.0   0.00  0.0    0.0      1
# 2010.0   0.00  0.0    0.0      2
# 2012.0   0.00  0.0    0.0      2
# 2013.0   0.00  0.0    0.0      4
# 2014.0  24.00  0.0  120.0      5
# 2015.0   0.00  0.0    0.0      7
# 2016.0  61.88  0.0  120.0      8
# 2017.0  72.53  0.0  305.0     19
# 2018.0  64.78  0.0  240.0     20
# 2019.0  56.00  0.0  240.0     13
# 2020.0  17.14  0.0  240.0     14
# 2021.0  46.00  0.0  300.0      9
# 2022.0    NaN  NaN    NaN      0
